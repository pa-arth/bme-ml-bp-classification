# %% [markdown]
# # 00 — Setup (local, RTX 4070)
#
# One-time setup. Run this notebook from a Jupyter kernel rooted at the project (i.e. opened from `<repo>/notebooks/`).
#
# 1. Adds the project root to `sys.path` so `import bme_ml` works.
# 2. Installs Python deps (incl. PyTorch with CUDA 12.1 wheels for the 4070).
# 3. Downloads the UCI Cuff-Less BP dataset to `<repo>/data/raw/` (~1–2 GB; ~5 min on first run).
# 4. Verifies CUDA visibility.
#
# If you've already pip-installed `requirements.txt` and torch in your env, you can skip cell 2.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print('project root:', PROJECT_ROOT)

# %%
# Install deps. PyTorch is pulled from the cu121 index for the 4070; if you
# already manage your own torch install, comment the second line out.
# !pip install -q -r '{PROJECT_ROOT}/requirements.txt'
# !pip install -q --index-url https://download.pytorch.org/whl/cu121 torch

# %%
from bme_ml.paths import setup_paths, download_dataset

paths = setup_paths()
print('raw       :', paths.raw)
print('processed :', paths.processed)
print('models    :', paths.models)

download_dataset(paths)
print('dataset ready:', sorted(paths.raw.iterdir()))

# %%
# CUDA sanity check.
import torch
print('torch       :', torch.__version__)
print('CUDA avail  :', torch.cuda.is_available())
if torch.cuda.is_available():
    print('device      :', torch.cuda.get_device_name(0))
    print('CUDA ver    :', torch.version.cuda)
